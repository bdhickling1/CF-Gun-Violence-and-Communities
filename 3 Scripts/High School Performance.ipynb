# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/brucehickling/Library/CloudStorage/Dropbox/Courses/CareerFoundry/Data Immersion/6_Advanced Analytics & Dashboard Design'

# %%
df_hs = pd.read_csv(os.path.join(path, '02 Data', 'HS Performance_AL-KY.csv'), index_col=0)
# Out:
# /var/folders/9d/wp_2lptx7pngxs5vccs361_c0000gn/T/ipykernel_24303/1059116131.py:1: DtypeWarning: Columns (4,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_hs = pd.read_csv(os.path.join(path, '02 Data', 'HS Performance_AL-KY.csv'), index_col=0)

# %%
df_hs.head()
# Out:
#                State  NCES LEA ID  LEA School  NCES SCH ID  Data Group  \
# School Year
# 2020-2021    ALABAMA          NaN  NaN    NaN          NaN         584
# 2020-2021    ALABAMA          NaN  NaN    NaN          NaN         584
# 2020-2021    ALABAMA          NaN  NaN    NaN          NaN         584
# 2020-2021    ALABAMA          NaN  NaN    NaN          NaN         584
# 2020-2021    ALABAMA          NaN  NaN    NaN          NaN         584
#
#                                               Data Description  Value  \
# School Year
# 2020-2021    Performance on Statewide Reading/Language Arts...  28.4%
# 2020-2021    Performance on Statewide Reading/Language Arts...    32%
# 2020-2021    Performance on Statewide Reading/Language Arts...    58%
# 2020-2021    Performance on Statewide Reading/Language Arts...    60%
# 2020-2021    Performance on Statewide Reading/Language Arts...    23%
#
#              Denominator  Numerator    Population  \
# School Year
# 2020-2021        46390.0        NaN  All Students
# 2020-2021          483.0        NaN  All Students
# 2020-2021          883.0        NaN  All Students
# 2020-2021          827.0        NaN  All Students
# 2020-2021           56.0        NaN  All Students
#
#                                                   Subgroup Characteristics  \
# School Year
# 2020-2021                              All Students in SEA             NaN
# 2020-2021    American Indian/Alaska Native/Native American             NaN
# 2020-2021                           Asian/Pacific Islander             NaN
# 2020-2021                                            Asian             NaN
# 2020-2021        Native Hawaiian or Other Pacific Islander             NaN
#
#                Age/Grade       Academic Subject  Program Type  \
# School Year
# 2020-2021    High School  Reading/Language Arts           NaN
# 2020-2021    High School  Reading/Language Arts           NaN
# 2020-2021    High School  Reading/Language Arts           NaN
# 2020-2021    High School  Reading/Language Arts           NaN
# 2020-2021    High School  Reading/Language Arts           NaN
#
#                         Outcome
# School Year
# 2020-2021    Percent Proficient
# 2020-2021    Percent Proficient
# 2020-2021    Percent Proficient
# 2020-2021    Percent Proficient
# 2020-2021    Percent Proficient

# %%
df_hs.shape
# Out:
# (921189, 17)

# %%
df_hs.drop(columns=df_hs.columns[1:6], inplace=True)

# %%
df_hs.head()
# Out:
#                State                                   Data Description  \
# School Year
# 2020-2021    ALABAMA  Performance on Statewide Reading/Language Arts...
# 2020-2021    ALABAMA  Performance on Statewide Reading/Language Arts...
# 2020-2021    ALABAMA  Performance on Statewide Reading/Language Arts...
# 2020-2021    ALABAMA  Performance on Statewide Reading/Language Arts...
# 2020-2021    ALABAMA  Performance on Statewide Reading/Language Arts...
#
#              Value  Denominator  Numerator    Population  \
# School Year
# 2020-2021    28.4%      46390.0        NaN  All Students
# 2020-2021      32%        483.0        NaN  All Students
# 2020-2021      58%        883.0        NaN  All Students
# 2020-2021      60%        827.0        NaN  All Students
# 2020-2021      23%         56.0        NaN  All Students
#
#                                                   Subgroup Characteristics  \
# School Year
# 2020-2021                              All Students in SEA             NaN
# 2020-2021    American Indian/Alaska Native/Native American             NaN
# 2020-2021                           Asian/Pacific Islander             NaN
# 2020-2021                                            Asian             NaN
# 2020-2021        Native Hawaiian or Other Pacific Islander             NaN
#
#                Age/Grade       Academic Subject  Program Type  \
# School Year
# 2020-2021    High School  Reading/Language Arts           NaN
# 2020-2021    High School  Reading/Language Arts           NaN
# 2020-2021    High School  Reading/Language Arts           NaN
# 2020-2021    High School  Reading/Language Arts           NaN
# 2020-2021    High School  Reading/Language Arts           NaN
#
#                         Outcome
# School Year
# 2020-2021    Percent Proficient
# 2020-2021    Percent Proficient
# 2020-2021    Percent Proficient
# 2020-2021    Percent Proficient
# 2020-2021    Percent Proficient
